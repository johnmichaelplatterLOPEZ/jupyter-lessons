# %% [markdown]
# # Focus on Functions

# %% [markdown]
# The following unknown side can be found using the pythagorean theorem.
# ![Screen%20Shot%202021-10-25%20at%201.26.50%20PM.png](attachment:Screen%20Shot%202021-10-25%20at%201.26.50%20PM.png)
# Compare the following two cells using Python Tutor. How are they similar, and how are they different? Discuss at least the variables involved and the order that code happens.

# %% [markdown]
# [response]

# %%
a = 5
b = 12

c_squared = a**2 + b**2

print( c_squared**(1/2) )

# %%
def square_root(n):
    return n**(1/2)

def solve_for_c(leg1, leg2):
    c_squared = leg1**2+leg2**2
    c = square_root( c_squared )
    return c

print( solve_for_c(5, 12) )

# %% [markdown]
# Functions are useful for a number of reasons. Here are just a few reasons programmers might use functions instead of just writing code line by line.
#
# - Helps guide problem solving by framing the "big picture"
# - Helps programmers reuse code instead of copy/pasting frequently used lines of code
# - When used well, makes code more "readable" and understandable

# %% [markdown]
# Which of the above reasons did you notice in code cell 2 compared with code cell 1?

# %% [markdown]
# [response]

# %% [markdown]
# Take our code from Lesson 2 and create a function `trapezoid_area` that takes 3 arguments: base1, base2 and height and returns the area of that trapezoid.

# %%
def trapezoid_area(base1, base2, height):
    #code here

# %% [markdown]
# Now use your function to solve the following 4 problems:
# ![Screen%20Shot%202021-10-25%20at%201.25.30%20PM.png](attachment:Screen%20Shot%202021-10-25%20at%201.25.30%20PM.png)

# %%
#either print all 4 answers from this cell
#or create a new code cell for each
