# %% [markdown]
# # Predicting output
#
# #### Predict the output of the following code cells *before* running them!

# %%
cat=10
dog=8
print(cat+dog)

# %%
cat=3
cat=4
cat=5
print(cat+4)

# %%
dog=4+2*5
print(dog-5)

# %%
dog=1
dog=dog+1
print(dog+1)

# %% [markdown]
# # Making Code more readable
# #### Which code are you more likely to understand as a solution to the problem? (part A or part B)
#
#
# Find the length of the missing side
# ![image-2.png](attachment:image-2.png)
# $a^{2}+b^{2}=c^{2};$
# $c=5, a=3$

# %%
#part A
import math

print(math.sqrt(5**2-3**2))

# %%
#part B
import math

a = 3
c = 5

b_squared = c**2 - a**2
b = math.sqrt(b_squared)
print(b)

# %% [markdown]
# # Finding Areas from a Formula
#
# #### Head to  https://cdn.kutasoftware.com/Worksheets/PreAlg/Area%20of%20Triangles.pdf
#
# #### Observe the following code:

# %%
base = float(input("The base is: "))
height = float(input("The height is: "))

area = 0.5*base*height

print("The area is:", area)

# %% [markdown]
# Try to do a few problems and figure out why the code works!

# %% [markdown]
# #### Now try to write code that works similarly for this page of problems! https://cdn.kutasoftware.com/Worksheets/PreAlg/Area%20of%20Trapezoids.pdf
